# %% [markdown]
# <a href="https://colab.research.google.com/github/insha-amreen/insha-assignment-2-/blob/main/INSHA_Assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
d = {'col1': [1, 2, 3], 'col2': [4, 5, 6], 'col3':[7,8,9]}

# %%
df = pd.DataFrame(d)
df
# Out:
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     8
# 2     3     6     9

# %% [markdown]
# Write a Pandas program to select all the rows from the given DataFrame based on the criteria if value 4 is present in it

# %%
df[df.isin([4]).any(axis=1)]
# Out:
#    col1  col2  col3
# 0     1     4     7

# %% [markdown]
# Write a Pandas program to reverse the order of a DataFrame columns

# %%
df.iloc[:,::-1]
# Out:
#    col3  col2  col1
# 0     7     4     1
# 1     8     5     2
# 2     9     6     3

# %% [markdown]
# Write a Pandas program to add one row in an existing DataFrame(any values)

# %%
df.loc[3]=[4,5,6]
df
# Out:
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     8
# 2     3     6     9
# 3     4     5     6

# %% [markdown]
# Write a Pandas program to delete DataFrame row(s) which has 5 in it

# %%
df = df.drop(df[df.isin([5]).any(axis=1)].index)
df
# Out:
#    col1  col2  col3
# 0     1     4     7
# 2     3     6     9
